# %%
import numpy as np

# %%
#題目
#english_score = np.array([55,89,76,65,48,70])
#math_score = np.array([60,85,60,68,np.nan,60])
#chinese_score = np.array([65,90,82,72,66,77])
#上 3 列共六位同學的英文、數學、國文成績，第一個元素代表第一位同學，舉例第一位同學英文 55 分、數學 60 分、國文 65 分，
#今天第五位同學因某原因沒來考試，導致數學成績缺值，運用上列數據回答下列問題。

# %%
#Q1:請計算各科成績平均、最大值、最小值、標準差，其中數學缺一筆資料可忽略？

# %%
english_score = np.array([55,89,76,65,48,70])

# %%
math_score = np.array([60,85,60,68,np.nan,60])

# %%
chinese_score = np.array([65,90,82,72,66,77])

# %%
#平均
english_score_mean = np.nanmean(english_score)
english_score_mean
# Out:
# 67.16666666666667

# %%
math_score_mean = np.nanmean(math_score)
math_score_mean
# Out:
# 66.6

# %%
chinese_score_mean = np.nanmean(chinese_score)
chinese_score_mean
# Out:
# 75.33333333333333

# %%
#最大值
english_score_max = np.nanmax(english_score)
english_score_max
# Out:
# 89

# %%
math_score_max = np.nanmax(math_score)
math_score_max
# Out:
# 85.0

# %%
chinese_score_max = np.nanmax(chinese_score)
chinese_score_max
# Out:
# 90

# %%
#最小值
english_score_min = np.nanmin(english_score)
english_score_min
# Out:
# 48

# %%
math_score_min = np.nanmin(math_score)
math_score_min
# Out:
# 60.0

# %%
chinese_score_min = np.nanmin(chinese_score)
chinese_score_min
# Out:
# 65

# %%
#標準差
english_score_std = np.nanstd(english_score)
english_score_std
# Out:
# 13.433995020924426

# %%
math_score_std = np.nanstd(math_score)
math_score_std
# Out:
# 9.707728879609279

# %%
chinese_score_std = np.nanstd(chinese_score)
chinese_score_std
# Out:
# 8.825468196582484

# %%
#Q2:第五位同學補考數學後成績為 55，請計算補考後數學成績平均、最大值、最小值、標準差？

# %%
math_score = np.array([60,85,60,68,55,60])

# %%
math_score_mean = np.nanmean(math_score)
math_score_mean
# Out:
# 64.66666666666667

# %%
math_score_max = np.nanmax(math_score)
math_score_max
# Out:
# 85

# %%
math_score_min = np.nanmin(math_score)
math_score_min
# Out:
# 55

# %%
math_score_std = np.nanstd(math_score)
math_score_std
# Out:
# 9.860132971832694

# %%
#Q3:用補考後資料找出與國文成績相關係數最高的學科？

# %%
np.corrcoef(chinese_score,math_score)
# Out:
# array([[1.        , 0.74056803],
#        [0.74056803, 1.        ]])

# %%
np.corrcoef(chinese_score,english_score)
# Out:
# array([[1.        , 0.97792828],
#        [0.97792828, 1.        ]])
