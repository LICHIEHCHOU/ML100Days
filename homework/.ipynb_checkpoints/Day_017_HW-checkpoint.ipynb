# %%
import numpy as np
import pandas as pd

# %%
#Q1:在速度較慢的時候，可以先從哪邊開始檢查？

# %%
#1.讀取資料型態的方式,可改用 pkl 檔讀取看看
#2.盡量使用Python 的內建函數
#3.採用向量化的資料處理方式,例:isin()

# %%
#Q2:資料過大時應採取什麼方式讓記憶體占用量下降？

# %%
#將欄位的型態降級，不要存太多元素在一個數字中
#例:將整數型態 int 改成 uint, 將浮點數型態 float64 改成 float32.
