# %%
#D34 掌握 A/B test的精隨 - 假設檢定的概念

# %%
#H_0 稱為虛無假設
#H_1 稱為對立假設

# %%
#Q1: 吃減肥藥能在一個月內瘦超過十公斤，研究人員想推翻第四台廣告業者的說法，請試著寫出 $H_0$ 與 $H_1$

#H_0: (p>=10)吃減肥藥能在一個月內瘦超過十公斤
#H_1: (p<10)吃減肥藥能在一個月內無法瘦超過十公斤

# %%
#Q2: 一位速食店店長認為其品牌在市場之佔有率至多為12%，於是該店長進行一個市場調查，一共訪問了3000為消費者，其中有311位表示喜歡該品牌，請試著寫出 $H_0$ 與 $H_1$ 。
p = 3000/311
p

#H_0: (p<12%)其品牌在市場之佔有率至多為 12%
#H_1: (p>=12%)其品牌在市場之佔有率超過 12%
# Out:
# 9.646302250803858
